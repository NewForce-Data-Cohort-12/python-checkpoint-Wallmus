# %% [markdown]
# # Python Checkpoint - Max Wallace

# %%
#you already know what it is, let's import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### open csv and look around

# %%
all_disneyplus = pd.read_csv('disney_plus.csv')

# all_disneyplus.shape
# all_disneyplus.info()
all_disneyplus.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
#            date_added  release_year rating   duration  \
# 0  September 24, 2021          2021  TV-PG     88 min
# 1  September 24, 2021          2011      G     93 min
# 2  September 24, 2021          2014  PG-13    127 min
# 3  September 22, 2021          2019  TV-PG  2 Seasons
# 4  September 22, 2021          2021   TV-Y   1 Season
#
#                               listed_in  \
# 0                           Documentary
# 1                 Comedy, Fantasy, Kids
# 2         Coming of Age, Drama, Romance
# 3  Animals & Nature, Docuseries, Family
# 4     Action-Adventure, Animation, Kids
#
#                                          description
# 0  Two Pixar filmmakers strive to bring their uni...
# 1  The puppies go on a spooky adventure through a...
# 2  Hazel and Gus share a love that sweeps them on...
# 3  Matt Beisner uses unique approaches to modifyi...
# 4  Spidey teams up with pals to become The Spidey...

# %% [markdown]
# ### Cleaning

# %%
#cleaning for only movies by ignoring entries where the string 'Season' is in the duration column
movies_disneyplus = all_disneyplus[~all_disneyplus['duration'].str.contains('Season', na=False)]

#convert duration to integer by extracting the first group of digits
movies_disneyplus['duration'] = movies_disneyplus['duration'].str.extract('(\d+)').astype(int)

#check it
movies_disneyplus.head()
# Out:
# C:\Users\BolognaColonel\AppData\Local\Temp\ipykernel_27204\2357697191.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_disneyplus['duration'] = movies_disneyplus['duration'].str.extract('(\d+)').astype(int)
#   show_id   type                        title                    director  \
# 0      s1  Movie                A Spark Story  Jason Sterman, Leanne Dare
# 1      s2  Movie               Spooky Buddies                Robert Vince
# 2      s3  Movie       The Fault in Our Stars                  Josh Boone
# 6      s7  Movie  Confessions of a Shopaholic                  P.J. Hogan
# 7      s8  Movie   Descendants: Royal Wedding               Salvador Simó
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 6  Isla Fisher, Hugh Dancy, Joan Cusack, John Goo...          United States
# 7  Dove Cameron, Sofia Carson, Booboo Stewart, Mi...                    NaN
#
#            date_added  release_year rating  duration  \
# 0  September 24, 2021          2021  TV-PG        88
# 1  September 24, 2021          2011      G        93
# 2  September 24, 2021          2014  PG-13       127
# 6  September 17, 2021          2009     PG       106
# 7  September 17, 2021          2021   TV-G        22
#
#                           listed_in  \
# 0                       Documentary
# 1             Comedy, Fantasy, Kids
# 2     Coming of Age, Drama, Romance
# 6  Comedy, Romance, Romantic Comedy
# 7       Animation, Fantasy, Musical
#
#                                          description
# 0  Two Pixar filmmakers strive to bring their uni...
# 1  The puppies go on a spooky adventure through a...
# 2  Hazel and Gus share a love that sweeps them on...
# 6  Becky writes a personal finance column en rout...
# 7             Mal and Ben’s wedding is finally here!

# %% [markdown]
# ### 1. Create a dataframe titled movie_ratings that contains the ratings (G, PG, TV-G, etc) and how many of those movies exist in the dataframe.

# %%
# show value counts for the 'ratings' column and save in new dataframe
movie_ratings = movies_disneyplus['rating'].value_counts().reset_index()
movie_ratings.head(10)
# Out:
#      rating  count
# 0         G    235
# 1        PG    226
# 2      TV-G    224
# 3     TV-PG    165
# 4     PG-13     60
# 5     TV-14     36
# 6     TV-Y7     36
# 7  TV-Y7-FV      6
# 8      TV-Y      2

# %% [markdown]
# ### 2. Using the movie_ratings dataframe, create a bar chart that displays the count of the top 5 movie ratings.

# %%
movie_ratings.nlargest(5, 'count').plot.bar(x='rating', y='count')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 3. Using movies_df, subset the data to create a new dataframe named year_duration that contains only two columns: release_year and duration

# %%
#new dataframe with just the two colums
year_duration = movies_disneyplus[['duration','release_year']]
year_duration.shape
year_duration.head()
# Out:
#    duration  release_year
# 0        88          2021
# 1        93          2011
# 2       127          2014
# 6       106          2009
# 7        22          2021

# %% [markdown]
# ### 4. Using your year_duration dataframe, filter for movies released between 1975 and 1984 (inclusive) and find the minimum duration, maximum duration

# %%
# only release_year from 1975 through 1984 please
filtered_years = year_duration[(year_duration['release_year'] >= 1975) & (year_duration['release_year'] <= 1984)]

# print min, max, and average
print("\nMinimum duration:", filtered_years['duration'].min())
print("Maximum duration:", filtered_years['duration'].max())
print("Average duration:", filtered_years['duration'].mean(),'\n')

#how many movies are in here?
print('1975-1984:',filtered_years.shape, '\nall movies:',movies_disneyplus.shape)
# Out:
# Minimum duration: 2
# Maximum duration: 135
# Average duration: 85.91428571428571
#
# 1975-1984: (35, 2)
# all movies: (991, 12)

# %% [markdown]
# ### 5. Using the year_duration dataframe, create a scatterplot that shows movie durations over the years. Add a descriptive title to your chart.

# %%
#plot thickens
plt.scatter(year_duration['release_year'], year_duration['duration'])
plt.title('Movie Durations Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Duration (min)')
plt.show()

# %% [markdown]
# ### Do you notice any correlation between release year and movie duration?

# %% [markdown]
# Movie duration appears to trend upward as the year increases, and the standard deviation increases as well with the variety of durations in modern day.

# %% [markdown]
# ### 6. Find the actual correlation value between release_year and duration.

# %%
# new dataframe with just two columns, and then corr() method
corr_year_duration = year_duration[['release_year', 'duration']]
print(corr_year_duration.corr())
# Out:
#               release_year  duration
# release_year      1.000000  0.241268
# duration          0.241268  1.000000

# %% [markdown]
# ### Based on the correlation value, is there a meaningful correlation between release year and duration?

# %% [markdown]
# At 0.24, we are seeing a positive correlation. This means that though there is variation, the average movie duration is going up over the years.

# %% [markdown]
# ### 7. Using movies_df, find which year had the most G-rated movie releases.

# %%
# using movies_disneyplus, which is the original 'all_disneyplus' dataframe with tv shows cleaned out
movies_disneyplus[movies_disneyplus['rating'] == 'G'].groupby('release_year').size().sort_values(ascending=False).head()
# Out:
# release_year
# 2003    12
# 2006    10
# 2008    10
# 2005    10
# 2011    10
# dtype: int64

# %% [markdown]
# ### 8.
# ##### 1. Find which year had the most total movie releases.

# %%
movies_disneyplus.groupby('release_year').size().sort_values(ascending=False).head()
# Out:
# release_year
# 2020    72
# 2019    60
# 2021    42
# 2018    32
# 2017    32
# dtype: int64

# %% [markdown]
# ##### 2. Create a new dataframe containing only movies from that year.

# %%
covid_movies = movies_disneyplus[movies_disneyplus['release_year'] == 2020]
covid_movies.head()
# Out:
#    show_id   type               title       director          cast country  \
# 10     s11  Movie   Jade Eyed Leopard            NaN  Jeremy Irons     NaN
# 65     s66  Movie    Shark vs. Surfer  Phil Stebbing   Billy Lloyd     NaN
# 66     s67  Movie     Shark vs. Whale            NaN   Ted Stewart     NaN
# 69     s70  Movie     What the Shark?            NaN   Robert Davi     NaN
# 75     s76  Movie  Most Wanted Sharks            NaN           NaN     NaN
#
#             date_added  release_year rating  duration  \
# 10  September 17, 2021          2020  TV-PG        44
# 65       July 23, 2021          2020  TV-14        44
# 66       July 23, 2021          2020  TV-PG        44
# 69       July 23, 2021          2020  TV-PG        44
# 75       July 16, 2021          2020  TV-PG        44
#
#                         listed_in  \
# 10  Animals & Nature, Documentary
# 65  Animals & Nature, Documentary
# 66  Animals & Nature, Documentary
# 69  Animals & Nature, Documentary
# 75  Animals & Nature, Documentary
#
#                                           description
# 10  Jade Eyed Leopard follows a leopard, Toto, thr...
# 65  Shark vs. Surfer visits shark-infested surf sp...
# 66  Marine biologist Ryan Johnson discovers rare b...
# 69  What the Shark? dives deep into the environmen...
# 75  In Most Wanted Sharks, Jeremiah Sullivan dives...

# %% [markdown]
# ##### 3. Convert the duration column to integers.

# %%
# whoops I did this earlier in the cleaning section up top

# %% [markdown]
# ##### 4. Use the IQR method to determine the upper and lower cutoffs for outliers.

# %%
# find quartiles from duration
Q1 = covid_movies['duration'].quantile(0.25)
Q3 = covid_movies['duration'].quantile(0.75)

#calculate IQR
IQR = Q3 - Q1

# calculate adn print lower and upper outlier cutoffs
upper = Q3 + 1.5 * IQR
lower = Q1 - 1.5 * IQR
print("Lower cutoff:",lower)
print("Upper cutoff:",upper)
# Out:
# Lower cutoff: -32.5
# Upper cutoff: 171.5

# %% [markdown]
# ##### 5. Calculate what percentage of movies from that year had durations that were statistical outliers.

# %%
# new dataframe with durations between the upper and lower outlier cutoffs
outlier_movies = covid_movies[(covid_movies['duration'] < lower) | (covid_movies['duration'] > upper)]
outlier_percentage = len(outlier_movies) / len(covid_movies) * 100
print(round(outlier_percentage, 2), '% of movies are outliers')
# Out:
# 2.78 % of movies are outliers

# %% [markdown]
# ### 9. Add a new column called length_category to movies_df that categorizes each movie as one of the following

# %%
# define function that returns one of three strings based on the duration length
def len_cat(duration):
    if duration < 30:
        return 'short'
    elif duration < 120:
        return 'average'
    else:
        return 'long'

#use our new len_cat function in the apply method with a row's duration_int value and store it in new column length_category
movies_disneyplus['length_category'] = movies_disneyplus['duration'].apply(len_cat)
movies_disneyplus.head()
# Out:
# C:\Users\BolognaColonel\AppData\Local\Temp\ipykernel_27204\1197849144.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_disneyplus['length_category'] = movies_disneyplus['duration'].apply(len_cat)
#   show_id   type                        title                    director  \
# 0      s1  Movie                A Spark Story  Jason Sterman, Leanne Dare
# 1      s2  Movie               Spooky Buddies                Robert Vince
# 2      s3  Movie       The Fault in Our Stars                  Josh Boone
# 6      s7  Movie  Confessions of a Shopaholic                  P.J. Hogan
# 7      s8  Movie   Descendants: Royal Wedding               Salvador Simó
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 6  Isla Fisher, Hugh Dancy, Joan Cusack, John Goo...          United States
# 7  Dove Cameron, Sofia Carson, Booboo Stewart, Mi...                    NaN
#
#            date_added  release_year rating  duration  \
# 0  September 24, 2021          2021  TV-PG        88
# 1  September 24, 2021          2011      G        93
# 2  September 24, 2021          2014  PG-13       127
# 6  September 17, 2021          2009     PG       106
# 7  September 17, 2021          2021   TV-G        22
#
#                           listed_in  \
# 0                       Documentary
# 1             Comedy, Fantasy, Kids
# 2     Coming of Age, Drama, Romance
# 6  Comedy, Romance, Romantic Comedy
# 7       Animation, Fantasy, Musical
#
#                                          description length_category
# 0  Two Pixar filmmakers strive to bring their uni...         average
# 1  The puppies go on a spooky adventure through a...         average
# 2  Hazel and Gus share a love that sweeps them on...            long
# 6  Becky writes a personal finance column en rout...         average
# 7             Mal and Ben’s wedding is finally here!           short

# %% [markdown]
# ### 10.
# ##### 1. Create a new column called gap that calculates the difference between the year a movie was added to Disney+ and its original release_year.

# %%
movies_disneyplus['year_added'] = movies_disneyplus['date_added'].str[-4:].astype(int)
movies_disneyplus['gap'] = movies_disneyplus['year_added'] - movies_disneyplus['release_year']
movies_disneyplus.head()
# Out:
# C:\Users\BolognaColonel\AppData\Local\Temp\ipykernel_27204\2730222009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_disneyplus['year_added'] = movies_disneyplus['date_added'].str[-4:].astype(int)
# C:\Users\BolognaColonel\AppData\Local\Temp\ipykernel_27204\2730222009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_disneyplus['gap'] = movies_disneyplus['year_added'] - movies_disneyplus['release_year']
#   show_id   type                        title                    director  \
# 0      s1  Movie                A Spark Story  Jason Sterman, Leanne Dare
# 1      s2  Movie               Spooky Buddies                Robert Vince
# 2      s3  Movie       The Fault in Our Stars                  Josh Boone
# 6      s7  Movie  Confessions of a Shopaholic                  P.J. Hogan
# 7      s8  Movie   Descendants: Royal Wedding               Salvador Simó
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 6  Isla Fisher, Hugh Dancy, Joan Cusack, John Goo...          United States
# 7  Dove Cameron, Sofia Carson, Booboo Stewart, Mi...                    NaN
#
#            date_added  release_year rating  duration  \
# 0  September 24, 2021          2021  TV-PG        88
# 1  September 24, 2021          2011      G        93
# 2  September 24, 2021          2014  PG-13       127
# 6  September 17, 2021          2009     PG       106
# 7  September 17, 2021          2021   TV-G        22
#
#                           listed_in  \
# 0                       Documentary
# 1             Comedy, Fantasy, Kids
# 2     Coming of Age, Drama, Romance
# 6  Comedy, Romance, Romantic Comedy
# 7       Animation, Fantasy, Musical
#
#                                          description length_category  \
# 0  Two Pixar filmmakers strive to bring their uni...         average
# 1  The puppies go on a spooky adventure through a...         average
# 2  Hazel and Gus share a love that sweeps them on...            long
# 6  Becky writes a personal finance column en rout...         average
# 7             Mal and Ben’s wedding is finally here!           short
#
#    year_added  gap
# 0        2021    0
# 1        2021   10
# 2        2021    7
# 6        2021   12
# 7        2021    0

# %% [markdown]
# ##### 2. Find the movie with the greatest gap.

# %%
movies_disneyplus.loc[movies_disneyplus['gap'].idxmax()]
# Out:
# show_id                                                        s1147
# type                                                           Movie
# title                                               Steamboat Willie
# director                                      Walt Disney, Ub Iwerks
# cast                                                     Walt Disney
# country                                                United States
# date_added                                         November 12, 2019
# release_year                                                    1928
# rating                                                         TV-Y7
# duration                                                           8
# listed_in                                    Animation, Family, Kids
# description        Watch Mickey Mouse's classic cartoon debut. Se...
# length_category                                                short
# year_added                                                      2019
# gap                                                               91
# Name: 1146, dtype: object

# %% [markdown]
# ##### 3. Find the average gap across all movies.

# %%
print(movies_disneyplus['gap'].mean())
# Out:
# 21.181634712411704
